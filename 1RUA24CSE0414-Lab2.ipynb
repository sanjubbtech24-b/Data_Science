# %%
import pandas as pd
import numpy as np
from sklearn.preprocessing import StandardScaler, MinMaxScaler

# %%
df = pd.read_csv("Automobile.csv")
df.head()
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0        8.0         307.0       130.0
# 1          buick skylark 320  15.0        8.0         350.0       165.0
# 2         plymouth satellite  18.0        8.0         318.0       150.0
# 3              amc rebel sst  16.0        8.0         304.0       150.0
# 4                ford torino  17.0        NaN         302.0       140.0
#
#    weight  acceleration  model_year origin
# 0  3504.0          12.0          70    usa
# 1  3693.0          11.5          70    usa
# 2  3436.0          11.0          70    usa
# 3  3433.0          12.0          70    usa
# 4  3449.0          10.5          70    usa

# %%
df.info()
df.shape
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 398 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          398 non-null    object
#  1   mpg           398 non-null    float64
#  2   cylinders     395 non-null    float64
#  3   displacement  395 non-null    float64
#  4   horsepower    386 non-null    float64
#  5   weight        396 non-null    float64
#  6   acceleration  395 non-null    float64
#  7   model_year    398 non-null    int64
#  8   origin        398 non-null    object
# dtypes: float64(6), int64(1), object(2)
# memory usage: 28.1+ KB
# (398, 9)

# %%
df.isnull().sum()
# Out:
# name             0
# mpg              0
# cylinders        3
# displacement     3
# horsepower      12
# weight           2
# acceleration     3
# model_year       0
# origin           0
# dtype: int64

# %%
df.dropna(subset = "horsepower", inplace = True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 386 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          386 non-null    object
#  1   mpg           386 non-null    float64
#  2   cylinders     383 non-null    float64
#  3   displacement  383 non-null    float64
#  4   horsepower    386 non-null    float64
#  5   weight        384 non-null    float64
#  6   acceleration  384 non-null    float64
#  7   model_year    386 non-null    int64
#  8   origin        386 non-null    object
# dtypes: float64(6), int64(1), object(2)
# memory usage: 30.2+ KB

# %%
df["horsepower"].fillna(df["horsepower"].median(), inplace=True)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 386 entries, 0 to 397
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   name          386 non-null    object
#  1   mpg           386 non-null    float64
#  2   cylinders     383 non-null    float64
#  3   displacement  383 non-null    float64
#  4   horsepower    386 non-null    float64
#  5   weight        384 non-null    float64
#  6   acceleration  384 non-null    float64
#  7   model_year    386 non-null    int64
#  8   origin        386 non-null    object
# dtypes: float64(6), int64(1), object(2)
# memory usage: 30.2+ KB
# /var/folders/dz/mssf7jjj0m7g6t776bksdgpc0000gn/T/ipykernel_7986/809309310.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
c=["horsepower"]
sc1=StandardScaler()
df[c]=sc1.fit_transform(df[c])
df.head()
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0        8.0         307.0    0.675237
# 1          buick skylark 320  15.0        8.0         350.0    1.595396
# 2         plymouth satellite  18.0        8.0         318.0    1.201042
# 3              amc rebel sst  16.0        8.0         304.0    1.201042
# 4                ford torino  17.0        NaN         302.0    0.938140
#
#    weight  acceleration  model_year origin
# 0  3504.0          12.0          70    usa
# 1  3693.0          11.5          70    usa
# 2  3436.0          11.0          70    usa
# 3  3433.0          12.0          70    usa
# 4  3449.0          10.5          70    usa

# %%
d=["horsepower"]
sc2=MinMaxScaler()
df[d]=sc2.fit_transform(df[d])
df.head()
# Out:
#                         name   mpg  cylinders  displacement  horsepower  \
# 0  chevrolet chevelle malibu  18.0        8.0         307.0    0.456522
# 1          buick skylark 320  15.0        8.0         350.0    0.646739
# 2         plymouth satellite  18.0        8.0         318.0    0.565217
# 3              amc rebel sst  16.0        8.0         304.0    0.565217
# 4                ford torino  17.0        NaN         302.0    0.510870
#
#    weight  acceleration  model_year origin
# 0  3504.0          12.0          70    usa
# 1  3693.0          11.5          70    usa
# 2  3436.0          11.0          70    usa
# 3  3433.0          12.0          70    usa
# 4  3449.0          10.5          70    usa

# %%
#MinMax Scaling is useful for this dataset because it normalizes all the features (price,mileage,horsepower) in the same range[0,1] which makes easy for comparision.
